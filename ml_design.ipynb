# %%
# %reset -f
# %run pylib/ml_fit paper doc
# Out:
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f956e601ad0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f95999eac50>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f95999e8510>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f95999e9190>
# /home/csstudent/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f956da75f90>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f956d17a7d0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f9599c30410>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f956dfe06d0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f956d1c2110>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f95999375d0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f9599934990>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f959904b510>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f9598f31850>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f956dfdec90>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f959935ab10>
# File `files/dr4_2_class_4_features.csv` exists--not overwriting.

# %%
show(f"""### Pulsar probability vs $d$ """)  
show_fig(self.psrprob_vs_d, 'd');
# Out:
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f956de77590>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f956d904750>

# %%
self.write_summary(True)
# Out:
# Wrote 6441-record summary, using model RandomForestClassifier(max_features=2), to `files/dr4_2_class_4_features.csv`
#   columns: ['source_type', 'glat', 'glon', 'variability', 'significance', 'class1', 'association', 'flags', 'r95', 'trainer', 'Ep', 'Fp', 'd', 'diffuse', 'Ep_unc', 'd_unc', 'p_pulsar']
# [Errno 2] No such file or directory: '/home/csstudent/Desktop/Files/diffuse/gll_iem_v07_hpx.fits'
