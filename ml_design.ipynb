# %%
# %reset -f
# %run pylib/ml_fit paper dark doc
# Out:
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f11e9cd60e0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f11e8f17fa0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f11e8f16170>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f11e8f0d180>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f11e8ef4490>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f11e817f880>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f11e80b3f70>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f11e813b520>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f11e813ab30>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f11e8f21780>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f11e908d360>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f11e81862c0>
# ...

# %%
fgl = Fermi4FGL()
# Out:
# Loaded Fermi 4FGL gll_psc_v32.fit: 7195 entries

# %%
show(f"""### Pulsar probability vs $d$ """)  
show_fig(self.psrprob_vs_d, 'd');
# Out:
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f11e85000a0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f11e8500970>

# %%
# self.write_summary(True)

# %%
if dark_mode:
    self=doc(nc=2,nf=3);
# Out:
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f124628f130>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f11e80b2f20>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f11e80b3130>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f11e80b1120>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f11e81ca530>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f11e829b4c0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f11e8647fa0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f11e86b5e70>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f11e8500d00>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f11e8f0b0d0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f11e86e0400>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f11e7f4a620>
# ...

# %%
df = self.df.copy()

df['lr_assoc'] = df.assoc_prob<0.8 #Bayesian association

show(
    pd.DataFrame(
    [   pd.Series(df.query('lr_assoc==True').groupby('class1').size(), name='LR'),
        pd.Series(df.query('lr_assoc==False').groupby('class1').size(), name='Bayesian'),
    ]).fillna(0).astype(int)
)
# Out:
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f11e89c94b0>
