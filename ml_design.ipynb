# %%
# %reset -f
# %run pylib/ml_fit paper dark doc
# Out:
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7545816b6ad0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x754580d10400>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x754580d19c90>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x754580d21b40>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x75457fc13f10>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x754580b301f0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x75457fc12fb0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x75457fc4da80>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x754580c2e1a0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x754580d109d0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x75457fc10790>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x75457fc62a40>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7545805fb3d0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x75457fb32f20>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x75458049f970>
# File `files/dr4_2_class_4_features.csv` exists--not overwriting.

# %%
show(f"""### Pulsar probability vs $d$ """)  
show_fig(self.psrprob_vs_d, 'd');
# Out:
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7545f43fddb0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x75458054caf0>

# %%
self.write_summary(True)
# Out:
# * Load diffuse file,  `/mnt/c/users/thbur/OneDrive/fermi/diffuse/gll_iem_v07_hpx.fits`
#   unit=$\rm{eV\ cm^{-2}\ s^{-1}\ deg^{-2}}$
#  select energy= 1000 MeV
# Wrote 6813-record summary, using model RandomForestClassifier(max_features=2), to `files/dr4_2_class_4_features.csv`
#   columns: ['source_type', 'glat', 'glon', 'variability', 'significance', 'class1', 'association', 'flags', 'r95', 'trainer', 'Ep', 'Fp', 'd', 'diffuse', 'Ep_unc', 'd_unc', 'p_pulsar']

# %%
if dark_mode:
    self=doc(nc=2,nf=2);
# Out:
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7545f4232c50>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x75457fe54160>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x75457fe57a00>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x75457fe576d0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x75457fe244c0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x75457fe54e50>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x75457fc4eda0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x754580bf5e10>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x75458075c520>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x754580fa6710>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x754580fa6110>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7545807b3040>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x754580c2cf40>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x75457fcc9660>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x75457fc91000>
# * Load diffuse file,  `/mnt/c/users/thbur/OneDrive/fermi/diffuse/gll_iem_v07_hpx.fits`
#   unit=$\rm{eV\ cm^{-2}\ s^{-1}\ deg^{-2}}$
#  select energy= 1000 MeV
# Wrote 6813-record summary, using model RandomForestClassifier(max_features=2), to `files/dr4_2_class_2_features.csv`
#   columns: ['source_type', 'glat', 'glon', 'variability', 'significance', 'class1', 'association', 'flags', 'r95', 'trainer', 'Ep', 'Fp', 'd', 'diffuse', 'Ep_unc', 'd_unc', 'p_pulsar']
