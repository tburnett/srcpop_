# %%
# %reset -f
# %run pylib/ml_fit dark
self, data = kde_setup()
show("""see [SC analysis](https://arxiv.org/pdf/2408.04973)""")
from pylib.kde import FeatureSpace
fs = FeatureSpace.runit(data, dark_mode, self.palette)
# Out:
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7feb3290f9a0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7feb3290f730>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7feb3290f7f0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7feb31fc0970>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7feb31fc0190>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7feb31fc3490>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7feb31fc3370>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7feb31fc20e0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7feb31fc30d0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7feb31fc3130>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7feb31fc0dc0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7feb32977190>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7feb329a3bb0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7feb32ac4310>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7feb3296c340>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7feb329f3ca0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7feb329f0640>
# array([[ 1.  , -0.53,  0.16],
#        [-0.53,  1.  , -0.31],
#        [ 0.16, -0.31,  1.  ]])
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7feb329f2a40>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7feb3296c130>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7feb32945120>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7feb32904fa0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7feb328ff6d0>
