# %%
# %run pylib/ml_fit
self=doc(3,2)
# Out:
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fd588183110>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fd52d8b37d0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fd52d8b2990>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fd52d8b3950>
# /home/csstudent/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fd53ee63290>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fd53c2c8f90>
# /home/csstudent/Desktop/Files/srcpop/pylib/ml_fit.py:501: UserWarning:
# The palette list has fewer values (2) than needed (3) and will cycle, which may produce an uninterpretable plot.
#   sns.kdeplot(dfq, ax=ax1,  x=dfq.log_epeak.clip(-1,2), hue='trainer',
# ...

# %%
# %run pylib/gevatar_fits.py
