# %%
# %run pylib/ml_fit dark
self=doc(2,2,3)
# Out:
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fbdb431b5b0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fbd4007dbd0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fbd3e6d4b80>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fbd3e6d46d0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fbd3e6d43d0>
# /home/burnett/miniconda3/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fbd3f12c850>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fbd3e72b220>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fbd3e620a30>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fbd3f26c9d0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fbd3e7980a0>
# ...

# %%
self.write_summary(True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /mnt/c/Users/thbur/onedrive/work/srcpop_/pylib/ml_fit.py:315, in MLfit.write_summary(self, overwrite)
#     314 try:
# --> 315     df['diffuse'] = get_diffuse(df) #self.get_diffuses(df)
#     316 except Exception as mst:
#
# File /mnt/c/Users/thbur/onedrive/work/srcpop_/pylib/ml_fit.py:303, in MLfit.write_summary.<locals>.get_diffuse(df)
#     302 from pylib.diffuse import Diffuse
# --> 303 diff = Diffuse()
#     304 sdirs = SkyCoord(df.glon, df.glat, unit='deg', frame='galactic')
#
# File /mnt/c/Users/thbur/onedrive/work/srcpop_/pylib/diffuse.py:46, in Diffuse.__init__(self, filename, field, energy)
#      45     xpix, ypix = wcs.world_to_pixel(SkyCoord(*coords, unit='deg', frame='galactic'))
# ---> 46     hpm = HPmap(hdus[0].data.T[(xpix+0.5).astype(int), (ypix+0.5).astype(int), field], name='')
#      47 else:
# ...
