# %%
# %run pylib/ml_fit
self=doc(3,2)
# Out:
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7363825c8610>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x736323e39930>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x736323e39630>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x736323e391b0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x736323e380a0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7363240cc760>
# /mnt/c/Users/thbur/onedrive/work/srcpop_/pylib/ml_fit.py:501: UserWarning:
# The palette list has fewer values (2) than needed (3) and will cycle, which may produce an uninterpretable plot.
#   sns.kdeplot(dfq, ax=ax1,  x=dfq.log_epeak.clip(-1,2), hue='trainer',
# /mnt/c/Users/thbur/onedrive/work/srcpop_/pylib/ml_fit.py:507: UserWarning:
# The palette list has fewer values (2) than needed (3) and will cycle, which may produce an uninterpretable plot.
# ...

# %%
# %run pylib/gevatar_fits.py
